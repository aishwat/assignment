# %%
# !pip install panda
import pandas as pd
import numpy as np
import json
import math

auditors = pd.read_csv("./auditors.csv") 
prices = pd.read_csv("./prices.csv") 
with open('./stores.json') as json_file:
    stores_data = json.load(json_file)
stores = pd.DataFrame(stores_data)
# stores.set_index('Store ID')
# print(stores)
# stores = {obj["Store ID"] for obj in stores_data}
# banners = {obj["Banner"] for obj in stores_data}
# regions = {obj["Region"] for obj in stores_data}
# print("stores:{} banners:{} regions:{}".format(len(stores),len(banners), len(regions)))
# print(auditors)
# print(prices)

# price_auditors=pd.merge(auditors,prices,on='Auditor ID')
# price_auditors_stores = pd.merge(price_auditors,stores,on='Store ID')
# price_auditors_stores.drop(["Region_x", "Last", "Date"], axis = 1, inplace = True) 
# print(price_auditors_stores[:5])
# print(len(prices["UPC"]))
# print(len(prices["UPC"].unique()))

# print(len(prices)) #12315
# print(len(price_auditors_stores)) #11511
# some stores missing in stores.json  

# stores_in_prices = prices["Store ID"].unique()
# stores_in_price_auditors_stores = price_auditors_stores["Store ID"].unique()
# print(len(prices_stores)) #20
# print(len(stores_in_price_auditors_stores)) #18
#after merging 2 stores missing
# print(list(set(stores_in_prices)-set(stores_in_price_auditors_stores)) )
#[38472, 60957] not in stores.json
####################

# price_stores = pd.merge(prices,stores,on='Store ID', how = "left" )
# price_stores.drop(["Auditor ID", "Date"], axis = 1, inplace = True) 

# cols = stores["Region"].unique().tolist() + ['Banner','UPC']
# newDF = pd.DataFrame(columns = cols) 
# price_stores.dropna(thresh=2)

# for index, row in price_stores.iterrows():
#     if(~row.isnull().any().any()):
#         if index%100==0 : print(index)
#         temp = newDF.loc[ (newDF['Banner'] == row['Banner']) & (newDF['UPC'] == row['UPC'])]
#         if(temp.empty):
#             newDF = newDF.append([{'Banner':row['Banner'], 'UPC':row['UPC'], row['Region']: row['Price'] }])
#         else:
#             newDF.loc[ (newDF['Banner'] == row['Banner']) & (newDF['UPC'] == row['UPC']), row['Region']] =row['Price']  

# # print(newDF)
# newDF.to_csv('newDF.csv', encoding='utf-8', index=False)
######################
auditors = pd.read_csv("./auditors.csv")
# Out:
# 0
# /Users/z002ktb/anaconda3/envs/deep-learning/lib/python3.7/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
#     Northern California  New York  Kansas  Texas  Hawaii       Banner  \
# 0                 24.95     22.13     NaN    NaN     NaN      Walmart
# 0                   NaN     23.29     NaN  22.59     NaN  Trader Joes
# 0                 49.71     44.12   42.41    NaN     NaN      Walmart
# 0                 25.75     22.83   21.90  22.10     NaN      Walmart
# 0                 18.81     16.66   16.02    NaN     NaN      Walmart
# 0                 33.32       NaN     NaN  28.77     NaN      Walmart
# 0                   NaN       NaN     NaN  13.19     NaN      Safeway
# 0                   NaN       NaN     NaN  15.09     NaN      Safeway
# 0                   NaN       NaN     NaN  59.09     NaN      Safeway
# 0                   NaN       NaN     NaN  57.89     NaN      Safeway
# 0                   NaN       NaN     NaN  48.29     NaN      Safeway
# 0                   NaN       NaN     NaN  29.89     NaN      Safeway
# 0                   NaN       NaN     NaN  13.89     NaN      Safeway
# 0                   NaN       NaN     NaN   5.19     NaN      Safeway
# 0                   NaN       NaN     NaN  26.99     NaN      Safeway
# 0                   NaN       NaN     NaN  22.49     NaN  Whole Foods
# 0                   NaN       NaN     NaN  25.89     NaN  Whole Foods
#
#           UPC
# 0   268588472
# 0   268588472
# 0   475245085
# 0   126967843
# 0   708930835
# 0   325885139
# 0   509419735
# 0   736362595
# 0   652377244
# 0   277394644
# 0   996849471
# 0   278354885
# 0   215480572
# 0   526069074
# 0   265077864
# 0   627831552
# 0   992105314
# 0    39408244
# 0   372268051
# 0   375916960
# 0   742726716
# 0   243131192
# 0   388544851
# 0   905914857
# 0   226080317
# 0   502816606
# 0   986134213
# 0   714264288
# 0   585091176
# 0   645118810
# ..        ...
# 0    44276570
# 0   849299370
# 0   451026029
# 0   454788216
# 0   588225773
# 0   502816606
# 0   622287285
# 0   654483249
# 0    60193187
# 0   336912254
# 0   860167579
# 0   442236507
# 0   643891644
# 0   649976289
# 0    51294147
# 0    48013704
# 0   509056495
# 0   596626474
# 0   311693284
# 0   996262978
# 0   574010167
# 0   377365657
# 0   266788198
# 0   448330081
# 0   430094535
# 0   251180255
# 0   872082334
# 0   641131808
# 0   277394644
# 0   126967843
#
# [4931 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': 'foo bar foo bar foo bar foo foo'.split(),
                   'B': 'one one two three two two one_ three'.split(),
                   'C': np.arange(8), 'D': np.arange(8) * 2})
print(df)
#      A      B  C   D
# 0  foo    one  0   0
# 1  bar    one  1   2
# 2  foo    two  2   4
# 3  bar  three  3   6
# 4  foo    two  4   8
# 5  bar    two  5  10
# 6  foo    one  6  12
# 7  foo  three  7  14

# temp = (df.loc[ (df['A'] == 'foo') & (df['B'] == 'one_')])
# if(temp.empty):
#     df['A'] = 'foo'
#     df['B'] = 'one'
# else:
#     temp['new'] = "faqq"
# print(temp)
newDF = pd.DataFrame(columns = ['A','B']) 
# for index, row in df.iterrows():
temp = (newDF.loc[ (newDF['A'] == 'foo') & (newDF['B'] == 'one')])
print(temp)
# Out:
#      A      B  C   D
# 0  foo    one  0   0
# 1  bar    one  1   2
# 2  foo    two  2   4
# 3  bar  three  3   6
# 4  foo    two  4   8
# 5  bar    two  5  10
# 6  foo   one_  6  12
# 7  foo  three  7  14
# Empty DataFrame
# Columns: [A, B]
# Index: []
