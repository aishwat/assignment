# %%
# !pip install panda
import pandas as pd
import json

auditors = pd.read_csv("./auditors.csv") 
prices = pd.read_csv("./prices.csv") 
with open('./stores.json') as json_file:
    stores_data = json.load(json_file)
stores = pd.DataFrame(stores_data)
# stores.set_index('Store ID')
# print(stores)
# stores = {obj["Store ID"] for obj in stores_data}
# banners = {obj["Banner"] for obj in stores_data}
# regions = {obj["Region"] for obj in stores_data}
# print("stores:{} banners:{} regions:{}".format(len(stores),len(banners), len(regions)))
# print(auditors)
# print(prices)

price_auditors=pd.merge(auditors,prices,on='Auditor ID')
price_auditors_stores = pd.merge(price_auditors,stores,on='Store ID')
price_auditors_stores.drop(["Region_x", "Last", "Date"], axis = 1, inplace = True) 
# print(price_auditors_stores[:5])
# print(len(prices["UPC"]))
# print(len(prices["UPC"].unique()))

# print(len(prices)) #12315
# print(len(price_auditors_stores)) #11511
# some stores missing in stores.json  

stores_in_prices = prices["Store ID"].unique()
stores_in_price_auditors_stores = price_auditors_stores["Store ID"].unique()
# print(len(prices_stores)) #20
# print(len(stores_in_price_auditors_stores)) #18
#after merging 2 stores missing
# print(list(set(stores_in_prices)-set(stores_in_price_auditors_stores)) )
#[38472, 60957] not in stores.json

####################
# store_upc_df = prices[["Store ID","UPC", "Price"]].drop_duplicates()
# unique_stores = stores['Store ID'].unique()

# for index, row in stores_.iterrows():
#     if(row['Store ID'] in unique_stores):
#         banner = (stores['Banner'][stores['Store ID'] == row['Store ID']].tolist()[0])
#         region = (stores['Region'][stores['Store ID'] == row['Store ID']].tolist()[0])
#         price = row['Price']
        
#         store_upc_df['Banner'] = banner
#         store_upc_df[region] = price
#     else: 
# #         print(row['Store ID'])
#         store_upc_df['Banner'] = '--'
    
# pd.set_option('display.max_columns', 7)
# pd.set_option('display.width', 200)
# print(store_upc_df)
# store_upc_df.to_csv('/Users/z002ktb/Desktop/file1.csv')
# Out:
#        Store ID        UPC  Price  ... New York  Kansas  Texas
# 0         66999  268588472  24.95  ...     6.59    1.99  37.39
# 1         66999  475245085  49.71  ...     6.59    1.99  37.39
# 2         66999  126967843  25.75  ...     6.59    1.99  37.39
# 3         66999  708930835  18.81  ...     6.59    1.99  37.39
# 4         66999  325885139  33.32  ...     6.59    1.99  37.39
# 5         66999  509419735  40.43  ...     6.59    1.99  37.39
# 6         66999  736362595  35.10  ...     6.59    1.99  37.39
# 7         66999  652377244  33.65  ...     6.59    1.99  37.39
# 8         66999  277394644  22.30  ...     6.59    1.99  37.39
# 9         66999  996849471  12.32  ...     6.59    1.99  37.39
# 10        66999  278354885  18.25  ...     6.59    1.99  37.39
# 11        66999  215480572  17.35  ...     6.59    1.99  37.39
# 12        66999  526069074   9.53  ...     6.59    1.99  37.39
# 13        66999  265077864   9.94  ...     6.59    1.99  37.39
# 14        66999  627831552  55.21  ...     6.59    1.99  37.39
